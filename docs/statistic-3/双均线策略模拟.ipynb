# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tushare as ts

# %%
df = ts.get_k_data('601318')
df.head()
# Out:
#          date    open   close    high     low    volume    code
# 0  2016-09-08  33.526  33.697  33.888  33.459  335396.0  601318
# 1  2016-09-09  33.745  33.774  34.136  33.602  440407.0  601318
# 2  2016-09-12  33.250  33.450  33.478  32.574  866024.0  601318
# 3  2016-09-13  33.316  33.069  33.316  32.764  317444.0  601318
# 4  2016-09-14  32.859  32.669  32.955  32.545  352136.0  601318

# %%
df.to_csv('601318.csv', index=False)

# %%
df = pd.read_csv('601318.csv')
df.head()
# Out:
#          date    open   close    high     low    volume    code
# 0  2016-09-08  33.526  33.697  33.888  33.459  335396.0  601318
# 1  2016-09-09  33.745  33.774  34.136  33.602  440407.0  601318
# 2  2016-09-12  33.250  33.450  33.478  32.574  866024.0  601318
# 3  2016-09-13  33.316  33.069  33.316  32.764  317444.0  601318
# 4  2016-09-14  32.859  32.669  32.955  32.545  352136.0  601318

# %%
df = pd.read_csv('601318.csv', index_col='date')[['open', 'close', 'high', 'low', 'volume']]
df.head(10)
# Out:
#               open   close    high     low    volume
# date
# 2016-09-08  33.526  33.697  33.888  33.459  335396.0
# 2016-09-09  33.745  33.774  34.136  33.602  440407.0
# 2016-09-12  33.250  33.450  33.478  32.574  866024.0
# 2016-09-13  33.316  33.069  33.316  32.764  317444.0
# 2016-09-14  32.859  32.669  32.955  32.545  352136.0
# 2016-09-19  32.764  33.307  33.450  32.764  372666.0
# 2016-09-20  33.307  33.193  33.307  33.145  146663.0
# 2016-09-21  33.231  33.021  33.316  32.840  352479.0
# 2016-09-22  33.155  33.345  33.688  33.155  541329.0
# 2016-09-23  33.383  33.231  33.526  33.069  314391.0

# %%
df.index[4]
# Out:
# '2016-09-14'

# %%
df['ma5'] = np.nan
df['ma30'] = np.nan


# for i in range(4, len(df)):
#     df.loc[df.index[i], 'ma5'] = df['close'][i-4:i+1].mean()

# for i in range(29, len(df)):
#     df.loc[df.index[i], 'ma30'] = df['close'][i-29:i+1].mean()
    

df['ma5'] = df['close'].rolling(5).mean()
df['ma30'] = df['close'].rolling(30).mean()

df
# Out:
#               open   close    high     low     volume      ma5       ma30
# date
# 2016-09-08  33.526  33.697  33.888  33.459   335396.0      NaN        NaN
# 2016-09-09  33.745  33.774  34.136  33.602   440407.0      NaN        NaN
# 2016-09-12  33.250  33.450  33.478  32.574   866024.0      NaN        NaN
# 2016-09-13  33.316  33.069  33.316  32.764   317444.0      NaN        NaN
# 2016-09-14  32.859  32.669  32.955  32.545   352136.0  33.3318        NaN
# 2016-09-19  32.764  33.307  33.450  32.764   372666.0  33.2538        NaN
# 2016-09-20  33.307  33.193  33.307  33.145   146663.0  33.1376        NaN
# 2016-09-21  33.231  33.021  33.316  32.840   352479.0  33.0518        NaN
# 2016-09-22  33.155  33.345  33.688  33.155   541329.0  33.1070        NaN
# 2016-09-23  33.383  33.231  33.526  33.069   314391.0  33.2194        NaN
# 2016-09-26  33.107  32.745  33.126  32.697   328526.0  33.1070        NaN
# 2016-09-27  32.602  32.726  32.764  32.564   458251.0  33.0136        NaN
# 2016-09-28  32.745  32.516  32.745  32.497   317332.0  32.9126        NaN
# 2019-04-22  87.220  84.960  88.090  84.500   932115.0  85.1500  77.775000
# 2019-04-23  84.750  86.060  87.380  84.500   678116.0  85.3600  78.350667
# 2019-04-24  86.080  85.030  86.880  83.550   812851.0  85.4700  78.876667
# 2019-04-25  84.350  83.400  84.990  83.150   655769.0  85.2900  79.272000
# 2019-04-26  83.000  83.110  84.430  82.800   648959.0  84.5120  79.615667
# 2019-04-29  83.880  86.430  87.130  83.300   946576.0  84.8060  80.035000
# 2019-04-30  86.500  85.720  87.480  84.530   636731.0  84.7380  80.392333
#
# [641 rows x 7 columns]

# %%
golden_cross = []
death_cross = []

for i in range(1, len(df)):
    if df['ma5'][i] >= df['ma30'][i] and df['ma5'][i-1] < df['ma30'][i-1]:
        golden_cross.append(df.index[i])
        
    if df['ma5'][i] < df['ma30'][i] and df['ma5'][i-1] >= df['ma30'][i-1]:
        death_cross.append(df.index[i])

# %%
golden_cross
# Out:
# ['2016-11-01',
#  '2017-01-18',
#  '2017-03-24',
#  '2017-04-26',
#  '2017-08-22',
#  '2017-10-12',
#  '2017-12-08',
#  '2017-12-21',
#  '2018-01-12',
#  '2018-03-19',
#  '2018-06-06',
#  '2018-07-24',
#  '2018-08-09',
#  '2018-08-24',
#  '2018-10-22',
#  '2018-11-06',
#  '2018-11-19',
#  '2019-01-21']

# %%
death_cross
# Out:
# ['2016-12-20',
#  '2017-03-02',
#  '2017-04-13',
#  '2017-08-11',
#  '2017-09-20',
#  '2017-12-07',
#  '2017-12-18',
#  '2017-12-29',
#  '2018-02-08',
#  '2018-03-28',
#  '2018-06-25',
#  '2018-08-07',
#  '2018-08-16',
#  '2018-10-15',
#  '2018-10-31',
#  '2018-11-14',
#  '2018-11-20']

# %%
sr1 = pd.Series(1, index=golden_cross)
sr1
sr2 = pd.Series(0, index=death_cross)
sr2

sr = sr2.append(sr1).sort_index()
sr
# Out:
# 2016-11-01    1
# 2016-12-20    0
# 2017-01-18    1
# 2017-03-02    0
# 2017-03-24    1
# 2017-04-13    0
# 2017-04-26    1
# 2017-08-11    0
# 2017-08-22    1
# 2017-09-20    0
# 2017-10-12    1
# 2017-12-07    0
# 2017-12-08    1
# 2017-12-18    0
# 2017-12-21    1
# 2017-12-29    0
# 2018-01-12    1
# 2018-02-08    0
# 2018-03-19    1
# 2018-03-28    0
# 2018-06-06    1
# 2018-06-25    0
# 2018-07-24    1
# 2018-08-07    0
# 2018-08-09    1
# 2018-08-16    0
# 2018-08-24    1
# 2018-10-15    0
# 2018-10-22    1
# 2018-10-31    0
# 2018-11-06    1
# 2018-11-14    0
# 2018-11-19    1
# 2018-11-20    0
# 2019-01-21    1
# dtype: int64

# %%
first_money = 100000

money = first_money
hold = 0 # 持有的股票数

sr1 = pd.Series(1, index=golden_cross)
sr2 = pd.Series(0, index=death_cross)
sr = sr2.append(sr1).sort_index()

for i in range(0, len(sr)):
    p = df['close'][sr.index[i]]  # 当前时间节点对应的收盘价
    if sr.iloc[i] == 1:
        #金叉
        buy = (money // p*100)
        hold += buy*100
        money -= buy*100*p
    else:
        money += hold*p
        hold = 0
        
p = df['close'][-1]
now_money = hold*p + money

now_money - first_money
# Out:
# 1.3412697638334086e+53
